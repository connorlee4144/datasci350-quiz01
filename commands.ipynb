# %% [markdown]
# 1. forked
# 2. git clone https://github.com/connorlee4144/datasci350-quiz01.git
# 3. cd datasci350-quiz01
# 4. mv ~/Downloads/commands.ipynb /Users/connorlee/datasci350-quiz01/
# 5. git checkout -b feature-update
# 6. mkdir reports
# 7. touch reports/summary.md
# 8. echo "This document provides a summary of the project updates." > reports/summary.md
# 9. git add reports
# 10. git commit -m "Add reports directory"
# 11. touch reports/file{1,2,3}.txt
# 12. git mv data/raw-data.csv data/input-data.csv
# 13. mkdir scripts/backup && cp scripts/*.py scripts/backup/
# 14. rm docs/documentation.md
# 15. git add .
# git commit -m "Update project files"
# 16. touch .gitignore
# 17. echo -e "temp/\ndataset0?.csv" > .gitignore
# 18. cat .gitignore
# 19. git add .gitignore && git commit -m "Add .gitignore file"
# 20. git checkout main
# git merge feature-update
# 21. git checkout main
# git add commands.ipynb
# git commit -m "Update of commands for Quiz 1"
# git push origin main
