# %% [markdown]
# 1. forked
# 2. git clone https://github.com/connorlee4144/datasci350-quiz01.git
# 3. cd datasci350-quiz01

# %% [markdown]
# # Verify the file is in the folder
# ls
#
# # Stage the file
# git add commands.ipynb
#
# # Commit it
# git commit -m "Add commands log from Google Colab"
#
# (DO ALL THIS LATER AFTER QUIZ)
